# %%
from routines.img_helper import *
from routines.microscopes_fwd import *
import numpy as np
import tifffile as tif
from matplotlib import colors
import sys, time
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from skimage import io

# %%
# p = io.imread("/Volumes/Lorentz/Kayna/ALTEM/Py(18)Pt(2)C(1)/2023_05_18/TIE/usaf_micro/aligned_imgj/images/RMAD/usaf_micro_AD_RAW.tiff")

# show_im(p)
# plt.imshow(p, cmap="gray")

# %% [markdown]
# ## Data Directories

# %%
b_c_lg = "/Volumes/Lorentz/Kayna/ALTEM/Py(18)Pt(2)C(1)/2023_05_25/TIE/bars_circles_lg/aligned_imgj/"
b_c_md = "/Volumes/Lorentz/Kayna/ALTEM/Py(18)Pt(2)C(1)/2023_05_25/TIE/bars_circles_md_sm_nano/aligned_imgj/"
b_sm = "/Volumes/Lorentz/Kayna/ALTEM/Py(18)Pt(2)C(1)/2023_05_25/TIE/bars_sm_nano/aligned_imgj/"
c_sm = "/Volumes/Lorentz/Kayna/ALTEM/Py(18)Pt(2)C(1)/2023_05_25/TIE/circles_sm_nano/aligned_imgj/"
hex_12 = "/Volumes/Lorentz/Kayna/ALTEM/Py(18)Pt(2)C(1)/2023_05_25/TIE/hex_col1_2_lg/aligned_imgj/"
hex_3 = "/Volumes/Lorentz/Kayna/ALTEM/Py(18)Pt(2)C(1)/2023_05_25/TIE/hex_col3_lg/aligned_imgj/"
hex_md = "/Volumes/Lorentz/Kayna/ALTEM/Py(18)Pt(2)C(1)/2023_05_25/TIE/hex_md_sm_nano/aligned_imgj/"
hex_sm = "/Volumes/Lorentz/Kayna/ALTEM/Py(18)Pt(2)C(1)/2023_05_25/TIE/hex_sm_nano/aligned_imgj/"
usaf_micro = "/Volumes/Lorentz/Kayna/ALTEM/Py(18)Pt(2)C(1)/2023_05_25/TIE/usaf_micro/aligned_imgj/"
usaf_nano = "/Volumes/Lorentz/Kayna/ALTEM/Py(18)Pt(2)C(1)/2023_05_25/TIE/usaf_nano/aligned_imgj/"

# %% [markdown]
# ## TIE DATA Directories

# %%
tie_b_c_lg_quad1 = io.imread(b_c_lg+"images_quad1/qc_0.0/bars_circles_lg_def_1216512.0_0.0_full_1216512.0_phase_b.tiff")
tie_b_c_lg_quad2 = io.imread(b_c_lg+"images_quad2/qc_0.0/bars_circles_lg_def_1216512.0_0.0_quad2_1216512.0_phase_b.tiff")
tie_b_c_lg_quad3 = io.imread(b_c_lg+"images_quad3/qc_0.0/bars_circles_lg_def_1216512.0_0.0_quad3_1216512.0_phase_b.tiff")
tie_b_c_lg_quad4 = io.imread(b_c_lg+"/images_quad4/qc_0.0/bars_circles_lg_def_1216512.0_0.0_quad4_1216512.0_phase_b.tiff")
tie_b_c_md_sec2 = io.imread(b_c_md+"images_quad1/qc_0.0/bars_circles_md_sm_def_2405376.0_0.0_quad1_2405376.0_phase_b.tiff")
tie_b_c_md_sec1 = io.imread(b_c_md+"images_quad2/qc_0.0/bars_circles_md_sm_def_2405376.0_0.0_quad2_2405376.0_phase_b.tiff")
tie_b_sm = io.imread(b_sm+"images/qc_0.0/bars_sm_nano_def_160128_0.0_full_160128.0_phase_b.tiff")
tie_c_sm = io.imread(c_sm+"images/qc_0.0/circles_sm_nano_def_160128_0.0_full_161280.0_phase_b.tiff")
tie_hex_12 = io.imread(hex_12+"images/qc_0.0/hexagons_lg_col1-2_def_2396160_0.0_full_1603584.0_phase_b.tiff")
tie_hex_3 = io.imread(hex_3+"images/qc_0.0/hexagons_lg_col3_def_2396160_0.0_full_1603584.0_phase_b.tiff")
tie_hex_md = io.imread(hex_md+"images/qc_0.0/hexs_md_def_640512_0.0_full_640512.0_phase_b.tiff")
tie_hex_sm = io.imread(hex_sm+"images/qc_0.0/hexagons_sm_nano_def_604800.0_0.0_full_604800.0.0_phase_b.tiff")
# tie_usaf_micro_quad1 = io.imread(usaf_micro+"")
# tie_usaf_micro_quad2 = io.imread(usaf_micro+"")
# tie_usaf_micro_quad3 = io.imread(usaf_micro+"")
# tie_usaf_micro_quad4 = io.imread(usaf_micro+"")
tie_usaf_micro = io.imread(usaf_micro+"images/qc_0.0/usaf_micro_1234944_0.0_full_1234944.0_phase_b.tiff")
tie_usaf_nano = io.imread(usaf_nano+"images/qc_0.0/usaf_nano_def_2658816_0.0_full_2658816.0_phase_b.tiff")

# %% [markdown]
# ## AD Data Directories

# %%
ad_b_c_lg_quad1 = io.imread(b_c_lg+"images_quad1/RMAD/quad1_1000_RAW.tif")
ad_b_c_lg_quad2 = io.imread(b_c_lg+"images_quad2/RMAD/quad2_1000_RAW.tif")
ad_b_c_lg_quad3 = io.imread(b_c_lg+"images_quad3/RMAD/quad3_1000_RAW.tif")
ad_b_c_lg_quad4 = io.imread(b_c_lg+"/images_quad4/RMAD/quad4_1000_RAW.tif")
ad_b_c_md_sec2 = io.imread(b_c_md+"images_quad1/RMAD/quad1_1000_RAW.tif")
ad_b_c_md_sec1 = io.imread(b_c_md+"images_quad2/RMAD/quad2_1000_RAW.tif")
ad_b_sm = io.imread(b_sm+"images/RMAD/sm_nano_bars_1000_RAW.tif")
ad_c_sm = io.imread(c_sm+"images/RMAD/sm_nano_circles_1000_RAW.tif")
ad_hex_12 = io.imread(hex_12+"images/RMAD/hex_col1-2_1000_RAW.tif")
ad_hex_3 = io.imread(hex_3+"images/RMAD/hex_col3_1000_RAW.tif")
ad_hex_md = io.imread(hex_md+"images/RMAD/hex_md_sm_nano_1000_RAW.tif")
ad_hex_sm = io.imread(hex_sm+"images/RMAD/hex_sm_nano_1000_RAW.tif")
# tie_usaf_micro_quad1 = io.imread(usaf_micro+"")
# tie_usaf_micro_quad2 = io.imread(usaf_micro+"")
# tie_usaf_micro_quad3 = io.imread(usaf_micro+"")
# tie_usaf_micro_quad4 = io.imread(usaf_micro+"")
micro = "/Volumes/Lorentz/Kayna/ALTEM/Py(18)Pt(2)C(1)/2023_05_25/TIE/usaf_micro/aligned_imgj/images/RMAD/"
usaf_micro_top = np.concatenate((io.imread(micro+"usaf_micro_quad2_1000_RAW.tif"), io.imread(micro+"usaf_micro_quad1_1000_RAW.tif")), axis = 1)
usaf_micro_bottom = np.concatenate((io.imread(micro+"usaf_micro_quad3_1000_RAW.tif"), io.imread(micro+"usaf_micro_quad4_1000_RAW.tif")), axis = 1)
usaf_micro_full = np.concatenate((usaf_micro_top, usaf_micro_bottom), axis=0)
# show_im(usaf_micro_full)
ad_usaf_micro = usaf_micro_full
ad_usaf_nano = io.imread(usaf_nano+"images/RMAD/usaf_nano_full_1000_RAW.tif")

# %% [markdown]
# ## Gradient of Phase Comparison Plots

# %%
# from microscopes_fwd import Plot_ColorMap

# show phase gradient
f, ax = plt.subplots(ncols=2, figsize = (14,8))

# Set x-y labels in nm for TIE
# xticks_tie = np.linspace(0, Nx_tie, 5)
# xticklabel_tie = xticks*d_pix
# yticks_tie = np.linspace(0, Ny_tie, 5)
# yticklabel_tie = yticks*d_pix


# Set x-y labels in nm for AD
# xticks_ad = np.linspace(0, Nx, 5)
# xticklabel_ad = xticks*d_pix
# yticks_ad = np.linspace(0, Ny, 5)
# yticklabel_ad = yticks*d_pix

# Plot the Phase Gradient TIE
t1 = np.copy(tie_usaf_micro)
t1=ndimage.gaussian_filter(t1-np.mean(t1),1,order=0)
gx=np.gradient(t1,axis=0)
gy=np.gradient(t1,axis=1)
rgb_map=Plot_ColorMap(Bx=gx, By=gy, hsvwheel=True)
ax[0].imshow(rgb_map)
ax[0].imshow(np.cos(t1*10), cmap='gray', alpha=0.1, vmin=-1, vmax=1)
ax[0].set_title("TIE Magnetic Induction");
# ax[0].set_ylabel("Position (nm)")
# ax[0].set_xlabel("Position (nm)")

# Plot the Phase Gradient AD
t2 = np.copy(ad_usaf_micro)
t2=ndimage.gaussian_filter(t2-np.mean(t2),20,order=0)
gx=np.gradient(t2,axis=0)
gy=np.gradient(t2,axis=1)
rgb_map=Plot_ColorMap(Bx=gx, By=gy, hsvwheel=True)
ax[1].imshow(rgb_map)
ax[1].imshow(np.cos(t2*10), cmap='gray', alpha=0.1, vmin=-1, vmax=1)
ax[1].set_title("RMAD Magnetic Induction");
# ax[1].set_ylabel("Position (nm)")
# ax[1].set_xlabel("Position (nm)");

#-------
ax[0].set_xticks([])#(xticks_tie)
# ax[0].set_xticklabels(xticklabel_tie)
ax[0].set_yticks([])#(yticks_tie)
# ax[0].set_yticklabels(yticklabel_tie)

ax[1].set_xticks([])#(xticks_ad)
# ax[1].set_xticklabels(xticklabel_ad)
ax[1].set_yticks([])#(yticks_ad)
# ax[1].set_yticklabels(yticklabel_ad)


# plt.rc("axes", labelsize=12)
plt.rc("axes", titlesize = 18)
# plt.rc("xtick", labelsize=11)
# plt.rc("ytick", labelsize=11)

f.tight_layout()


# plt.savefig("/home/ktrujillo/Lorentz/Kayna/ALTEM/2023_02_07/Cr2_Py16_Cr2/TFS/TIE/500_nano/aligned_imgj/data_analysis_crop_2405_2404/Grad_MagInd_TIE_qc0.0001_LF500_HF250_AD_noaxes.png")

# %%
from PyLorentz.PyTIE.TIE_helper import show_2D


show_2D()

# %% [markdown]
# ## Line Plots

# %%
## along the x-direction across the two squares in the center

fig, ax = plt.subplots(figsize=(14,5))
ax.plot(tie_b_c_lg_quad1[1110,0:1704], 'k-', linewidth=2, label="TIE")
ax.plot(ad_b_c_lg_quad1[1110,0:1704], "r--", linewidth=2, label="Reverse-Mode AD") #610:1610,360], 'r--', linewidth=2)
ax.legend(loc="lower center")
ax.set_title("Phase Across Line  ")

ax.set_ylabel(r"$\partial\phi / \partial x$ (rad/nm)")
ax.set_xlabel("Line Profile Position (nm)")
plt.rc("axes", labelsize=12)
plt.rc("axes", titlesize = 14)
plt.rc("legend", fontsize=11)


# xticks = np.linspace(0, Nx, 5)
# xticklabel = xticks*d_pix

# ax.set_xticks(xticks)
# ax.set_xticklabels(xticklabel)

# %%
show_im(tie_b_c_lg_quad2)
show_im(tie_b_c_lg_quad1)

# %%
test21 = np.concatenate((tie_b_c_lg_quad2[:], tie_b_c_lg_quad1[:]), axis=1)
test34 = np.concatenate((tie_b_c_lg_quad3, tie_b_c_lg_quad4), axis = 1)
show_im(test21)
show_im(test34)

test1234 = np.concatenate((test21, test34), axis = 0)
show_im(test1234)

# %%
# ?np.concatenate
# Out:
# Docstring:
# concatenate((a1, a2, ...), axis=0, out=None, dtype=None, casting="same_kind")
#
# Join a sequence of arrays along an existing axis.
#
# Parameters
# ----------
# a1, a2, ... : sequence of array_like
#     The arrays must have the same shape, except in the dimension
#     corresponding to `axis` (the first, by default).
# axis : int, optional
#     The axis along which the arrays will be joined.  If axis is None,
#     arrays are flattened before use.  Default is 0.
# out : ndarray, optional
#     If provided, the destination to place the result. The shape must be
#     correct, matching that of what concatenate would have returned if no
#     out argument were specified.
# dtype : str or dtype
#     If provided, the destination array will have this dtype. Cannot be
#     provided together with `out`.
#
#     .. versionadded:: 1.20.0
#
# casting : {'no', 'equiv', 'safe', 'same_kind', 'unsafe'}, optional
# ...

# %%
tie =
